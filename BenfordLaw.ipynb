# %%
Mxlim = int(input("INPUT MAX LIMIT TO FIND (<= 100000 HIGHLY RECOMMENDED) :"))
fib = []
fib.append(1)
fib.append(1)
# Out:
# INPUT MAX LIMIT TO FIND (<= 100000 HIGHLY RECOMMENDED) :1000

# %%
for i in range(2,Mxlim):
    fib.append(fib[i-1]+fib[i-2])

# %%
FirstDigit = []
for i in range(1,11): FirstDigit.append(0)
for i in range(1,Mxlim):
    FirstDigit[int(str(fib[i])[0])] += 1

# %%
FirstDigit = [i/(Mxlim-1) for i in FirstDigit]
for i, val in enumerate(FirstDigit):
    if i==0 : continue
    print("Probability for Digit "+str(i)+" : ",end="")
    print("%.16f"%val)
# Out:
# Probability for Digit 1 : 0.3003003003003003
# Probability for Digit 2 : 0.1771771771771772
# Probability for Digit 3 : 0.1251251251251251
# Probability for Digit 4 : 0.0960960960960961
# Probability for Digit 5 : 0.0800800800800801
# Probability for Digit 6 : 0.0670670670670671
# Probability for Digit 7 : 0.0560560560560561
# Probability for Digit 8 : 0.0530530530530531
# Probability for Digit 9 : 0.0450450450450450

# %%
def logFunc(x):
    return np.log10((x+1)/x)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,10,0.1)
plt.plot(x,logFunc(x),color='red')
plt.plot(FirstDigit,color='blue')
plt.xlim(1.0,10.0)
plt.show()
# Out:
# C:\Users\jbs\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %%
Deltalist = []
for i in range(1,10):
    Deltalist.append(logFunc(i)-FirstDigit[i])
for i,val in enumerate(Deltalist):
    print("Error in Digit " + str(i+1) + " : ",end="")
    print("%.16f"%val)
# Out:
# Error in Digit : 1 :-0.0000001073463198
# Error in Digit : 2 :-0.0001263627064950
# Error in Digit : 3 :-0.0000737646418251
# Error in Digit : 4 :0.0001003320399596
# Error in Digit : 5 :-0.0000266747444544
# Error in Digit : 6 :0.0001401089625464
# Error in Digit : 7 :-0.0000138536023713
# Error in Digit : 8 :-0.0001526080656700
# Error in Digit : 9 :0.0001529301046295
